# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
df = pd.read_csv('yellow_tripdata_2024-01.csv', nrows=100)

# %%
df
# Out:
#     VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0          2  2024-01-01 00:57:55   2024-01-01 01:17:43              1.0
# 1          1  2024-01-01 00:03:00   2024-01-01 00:09:36              1.0
# 2          1  2024-01-01 00:17:06   2024-01-01 00:35:01              1.0
# 3          1  2024-01-01 00:36:38   2024-01-01 00:44:56              1.0
# 4          1  2024-01-01 00:46:51   2024-01-01 00:52:57              1.0
# ..       ...                  ...                   ...              ...
# 95         2  2024-01-01 00:54:16   2024-01-01 01:27:40              1.0
# 96         2  2024-01-01 00:13:58   2024-01-01 00:33:39              1.0
# 97         2  2024-01-01 00:35:53   2024-01-01 00:47:59              1.0
# 98         2  2024-01-01 00:50:28   2024-01-01 01:38:39              1.0
# 99         2  2024-01-01 00:18:24   2024-01-01 00:30:39              1.0
#
#     trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# ...

# %%
from sqlalchemy import create_engine

# %%
import psycopg2
print("psycopg2 installed successfully!")
# Out:
# psycopg2 installed successfully!

# %%
engine = create_engine("postgresql://root:root@localhost:5432/ny_taxi")

# %%
print(pd.io.sql.get_schema(df, name="yellow_taxi_data", con=engine))
# Out:
# CREATE TABLE yellow_taxi_data (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TEXT,
# 	tpep_dropoff_datetime TEXT,
# 	passenger_count FLOAT(53),
# 	trip_distance FLOAT(53),
# 	"RatecodeID" FLOAT(53),
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53),
# 	"Airport_fee" FLOAT(53)
# )

# %%
df_iter = pd.read_csv('yellow_tripdata_2024-01.csv', iterator=True, chunksize=100000)

# %%
df = next(df_iter)

# %%
len(df)
# Out:
# 100000

# %%
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)

# %%
df
# Out:
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             2  2024-01-01 00:57:55   2024-01-01 01:17:43              1.0
# 1             1  2024-01-01 00:03:00   2024-01-01 00:09:36              1.0
# 2             1  2024-01-01 00:17:06   2024-01-01 00:35:01              1.0
# 3             1  2024-01-01 00:36:38   2024-01-01 00:44:56              1.0
# 4             1  2024-01-01 00:46:51   2024-01-01 00:52:57              1.0
# ...         ...                  ...                   ...              ...
# 99995         1  2024-01-02 13:34:18   2024-01-02 13:38:13              1.0
# 99996         1  2024-01-02 13:47:42   2024-01-02 13:59:26              1.0
# 99997         2  2024-01-02 13:23:51   2024-01-02 13:36:29              1.0
# 99998         2  2024-01-02 13:42:04   2024-01-02 13:48:39              1.0
# 99999         2  2024-01-02 13:54:12   2024-01-02 13:57:25              1.0
#
# ...

# %%
df.head(n=0).to_sql(name='yellow_taxi_data', con=engine, if_exists='replace')
# Out:
# 0

# %%
# %time df.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')
# Out:
# CPU times: user 4.13 s, sys: 90.5 ms, total: 4.23 s
# Wall time: 6.5 s
# 1000

# %%
from time import time

# %%
df_iter = pd.read_csv('yellow_tripdata_2024-01.csv', iterator=True, chunksize=100000, low_memory=False)

while True:
    try:
        t_start = time()
        df = next(df_iter)
        df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
        df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
        df.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')
        t_end = time()
        print('Inserted another chunk..., took %.3f seconds' % (t_end - t_start))

    except StopIteration:
        print("All chunks processed. Exiting loop.")
        break
# Out:
# Inserted another chunk..., took 6.542 seconds
# Inserted another chunk..., took 6.404 seconds
# Inserted another chunk..., took 6.461 seconds
# Inserted another chunk..., took 6.368 seconds
# Inserted another chunk..., took 6.441 seconds
# Inserted another chunk..., took 6.406 seconds
# Inserted another chunk..., took 6.495 seconds
# Inserted another chunk..., took 6.520 seconds
# Inserted another chunk..., took 6.536 seconds
# Inserted another chunk..., took 6.472 seconds
# Inserted another chunk..., took 6.420 seconds
# Inserted another chunk..., took 6.398 seconds
# Inserted another chunk..., took 6.500 seconds
# Inserted another chunk..., took 6.450 seconds
# Inserted another chunk..., took 6.449 seconds
# Inserted another chunk..., took 6.443 seconds
# Inserted another chunk..., took 6.419 seconds
# Inserted another chunk..., took 6.450 seconds
# Inserted another chunk..., took 6.451 seconds
# Inserted another chunk..., took 6.413 seconds
# ...

# %%
while True:
    t_start = time()
    df = next(df_iter)
    df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
    df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)

    df.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')

    t_end = time()

    print('inserted amother chunck..., took %.3f second' % (t_end - t_start))
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[24], line 3
#       1 while True:
#       2     t_start = time()
# ----> 3     df = next(df_iter)
#       4     df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
#       5     df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1843, in TextFileReader.__next__(self)
#    1841 def __next__(self) -> DataFrame:
#    1842     try:
# -> 1843         return self.get_chunk()
#    1844     except StopIteration:
#    1845         self.close()
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1985, in TextFileReader.get_chunk(self, size)
#    1983         raise StopIteration
#    1984     size = min(size, self.nrows - self._currow)
# -> 1985 return self.read(nrows=size)
#
# ...

# %%
# !wget https://d37ci6vzurychx.cloudfront.net/misc/taxi_zone_lookup.csv
# Out:
# --2025-02-03 22:20:58--  https://d37ci6vzurychx.cloudfront.net/misc/taxi_zone_lookup.csv
# Resolving d37ci6vzurychx.cloudfront.net (d37ci6vzurychx.cloudfront.net)... 2600:9000:26cc:3e00:b:20a5:b140:21, 2600:9000:26cc:4e00:b:20a5:b140:21, 2600:9000:26cc:8400:b:20a5:b140:21, ...
# Connecting to d37ci6vzurychx.cloudfront.net (d37ci6vzurychx.cloudfront.net)|2600:9000:26cc:3e00:b:20a5:b140:21|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12331 (12K) [text/csv]
# Saving to: ‘taxi_zone_lookup.csv’
#
# taxi_zone_lookup.cs 100%[===================>]  12.04K  --.-KB/s    in 0s
#
# 2025-02-03 22:20:59 (74.0 MB/s) - ‘taxi_zone_lookup.csv’ saved [12331/12331]

# %%
df_zones = pd.read_csv('taxi_zone_lookup.csv')

# %%
print(df_zones.head())
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
df_zones.to_sql(name='zones', con=engine, if_exists='replace')
# Out:
# 265
